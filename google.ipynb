# %%
import dotenv
from google_search import get_content_by_url, get_search_results, search_inner

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
query = "Хачапури в ессентуках"
results = await get_search_results(query)

# %%
print(results)
# Out:
# **1. Хачапури — заказать доставку от 30 минут в Ессентуках**
# Link: https://eda.yandex.ru/Essentuki/d/gruzinskaya/hachapuri
# Snippet: Хачапури — заказать в сервисе Яндекс Еда с доставкой в Ессентуках от 30 минут. В офис или на дом. Первая доставка из ресторанов бесплатно.
#
# **2. Хачапури по-аджарски - цены от 190 руб. в Ессентуках - 7 мест ...**
# Link: https://zoon.ru/stavropol/gorod-essentuki/m/hachapuri_po-adzharski/
# Snippet: Хачапури по-аджарски - средняя стоимость услуг в Ессентуках 350 руб. Хачапури - Хачапури по-аджарски ☑️ 7 мест на Zoon.ru с отзывами посетителей, ...
#
# **3. Где можно поесть хачапури по аджарски в г. Ессентуки на карте ...**
# Link: https://2gis.ru/essentuki/search/%D0%93%D0%B4%D0%B5%20%D0%BC%D0%BE%D0%B6%D0%BD%D0%BE%20%D0%BF%D0%BE%D0%B5%D1%81%D1%82%D1%8C%20%D1%85%D0%B0%D1%87%D0%B0%D0%BF%D1%83%D1%80%D0%B8%20%D0%BF%D0%BE%20%D0%B0%D0%B4%D0%B6%D0%B0%D1%80%D1%81%D0%BA%D0%B8
# ...
