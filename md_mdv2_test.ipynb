# %%
from telegramify_markdown import telegramify

# %%
# Пример Markdown-текста
markdown_text = """
# Заголовок 1
**Жирный текст** и *курсивный текст*
[Ссылка](https://example.com)
- Пункт 1
- Пункт 2
`Код в строке`
"""

# %%
markdown_v2_text = await telegramify(markdown_text)

print("📄 Telegram MarkdownV2:")
print(markdown_v2_text)
# Out:
# 📄 Telegram MarkdownV2:
# [Text(content='\n*📌 Заголовок 1*\n*Жирный текст* и *курсивный текст*\n[Ссылка](https://example\\.com)\n⦁ Пункт 1\n⦁ Пункт 2\n  `Код в строке`\n', content_type=<ContentTypes.TEXT: 'text'>)]

# %%
import telegramify_markdown


results = await telegramify("Привет! Я бот, интегрированный с ChatGPT. Задайте мне вопрос.")
for item in results:
        print(type(item))
        if isinstance(item, telegramify_markdown.type.Text):
            print(item.content)
# Out:
# <class 'telegramify_markdown.type.Text'>
# Привет\! Я бот, интегрированный с ChatGPT\. Задайте мне вопрос\.
